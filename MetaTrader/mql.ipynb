# %%
from datetime import datetime
import metatrader as mt
import

# %%
Login = 52643494
Password = '580MG!@erMeVOY'
Server = 'ICMarketsSC-Demo'

# %%
# Out:
# /home/falcon/.local/lib/python3.14/site-packages/metatrader/__init__.py

# %%
mt.login(Login,Password,Server)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mt.login(Login,Password,Server)
#
# AttributeError: module 'metatrader' has no attribute 'login'

# %%
rate = mt.copy_rates_from('TSLA.NAS')

# %%
rate

# %%
Account_Info = mt.account_info()
print(Account_Info)

# %%
mt.initialize()

# %%
mt.symbol_info('TSLA.NSA').capitalize
